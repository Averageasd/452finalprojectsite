# %% [markdown]
# <a href="https://colab.research.google.com/github/Averageasd/452finalprojectsite/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.array([1,2,3])
